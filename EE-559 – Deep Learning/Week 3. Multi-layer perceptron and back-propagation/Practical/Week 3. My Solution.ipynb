# %% [markdown]
# # EE-559: Practical Session 3

# %% [markdown]
# ## Introduction

# %% [markdown]
# The objective of this session is to implement a multi-layer perceptron with one hidden layer from
# scratch and test it on MNIST.
#
# You can get information about the practical sessions and the provided helper functions on the course's
# website.

# %%
import math
import torch
from torch import Tensor

import dlc_practical_prologue as prologue

# %% [markdown]
# ## Activation function

# %% [markdown]
# Write the two functions
#
# 1. def sigma(x)
# 1. def dsigma(x)
#
# that take as input a float tensor and returns a tensor of same size, obtained by applying component-wise
# respectively tanh, and the first derivative of tanh.
#
# **Hint**: The functions should have no python loop, and use in particular torch.tanh , torch.exp ,
# torch.mul , and torch.pow . My versions are 34 and 62 character long.

# %%
def sigma(x):
    return x.tanh()

def dsigma(x):
    return 4 * (x.exp() + x.mul(-1).exp()).pow(-2)

# %% [markdown]
# ## Loss

# %% [markdown]
# Write the two functions
# 1. def loss(v, t)
# 1. def dloss(v, t)
#
# that take as input two float tensors of same dimensions with v the predicted tensor and t the target
# one, and return respectively, and a tensor of same size equal to the gradient of that quantity as a function of v.
#
# **Hint**: The functions should have no python loop, and use in particular torch.sum , torch.pow . My
# versions are 48 and 40 character long.

# %%
def loss(v, t):
    return (v - t).pow(2).sum()

def dloss(v, t):
    return 2 * (v - t)

# %% [markdown]
# ## Forward and backward passes

# %% [markdown]
# Write a function
#
# def forward_pass(w1, b1, w2, b2, x)
#
# whose arguments correspond to an input vector to the network, and the weight and bias of the two
# layers, and returns a tuple composed of the corresponding x(0), s(1), x(1), s(2), and x(2).
#
# Write a function
#
# def backward_pass(w1, b1, w2, b2, t, x, s1, x1, s2, x2, dl_dw1, dl_db1, dl_dw2, dl_db2)
#
#
# whose arguments correspond to the target vector, the quantities computed by the forward pass, and
# the tensors used to store the cumulated sums of the gradient on individual samples, and update the
# latters according to the formula of the backward pass.
#
# **Hint**: The functions should have no python loop, and use in particular torch.t , torch.mv ,
# torch.mm , and torch.view , and the functions previously written. The main difficulty is to deal
# properly with the tensor size and transpose. My versions are 165 and 436 character long.

# %%
def forward_pass(w1, b1, w2, b2, x):
    x0 = x
    s1 = w1.mv(x0) + b1
    x1 = sigma(s1)
    s2 = w2.mv(x1) + b2
    x2 = sigma(s2)

    return x0, s1, x1, s2, x2

def backward_pass(w1, b1, w2, b2,
                  t,
                  x, s1, x1, s2, x2,
                  dl_dw1, dl_db1, dl_dw2, dl_db2):
    x0 = x
    dl_dx2 = dloss(x2, t)
    dl_ds2 = dsigma(s2) * dl_dx2
    dl_dx1 = w2.t().mv(dl_ds2)
    dl_ds1 = dsigma(s1) * dl_dx1

    dl_dw2.add_(dl_ds2.view(-1, 1).mm(x1.view(1, -1)))
    dl_db2.add_(dl_ds2)
    dl_dw1.add_(dl_ds1.view(-1, 1).mm(x0.view(1, -1)))
    dl_db1.add_(dl_ds1)

# %% [markdown]
# ## Training the network

# %% [markdown]
# Write the code to train and test a MLP with one hidden layer of 50 units. This network should have an
# input dimension of 784, which is the dimension of the MNIST training set, and an output dimension
# of 10, which is the number of classes.
#
# You code should:
#
# 1. Load the data using the provided prologue.load_data function, with one-hot label vectors
# and normalized inputs. Multiply the target label vectors by sigma = 0:9 (so that they are strictly in
# the value range of tanh).
# 1. Create the four weight and bias tensors, and fill them with random values sampled according to
# N(0; epsillon) with epsilon = 1e-6.
# 1. Create the four tensors to sum up the gradients on individual samples, with respect to the
# weights and biases.
# 1. Perform 1; 000 gradient steps with a step size nu equal to 0:1 divided by the number of training
# samples.
#
# Each of these steps requires to reset to zero the tensors for summing up the gradients, and
# doing a forward and a backward pass for each training example.
#
# Compute and print the training loss, training error and test error after every step using the class
# of maximum response as the predicted one.
#
# **Hint**: My solution is 1987 character long and achieves 3:6% training error and 15:70% test error with
# 50 hidden units. It takes 1min40s to nish on a Intel i7 with no GPU, using the default small sets of
# prologue.load_data.

# %%
train_input, train_target, test_input, test_target = prologue.load_data(one_hot_labels = True,
                                                                        normalize = True)

nb_classes = train_target.size(1)
nb_train_samples = train_input.size(0)

zeta = 0.90

train_input = train_input * zeta
test_input = test_input * zeta

nb_hidden = 50
eta = 1e-1 / nb_train_samples
epsilon = 1e-6

w1 = Tensor(nb_hidden, train_input.size(1)).normal_(0, epsilon)
b1 = Tensor(nb_hidden).normal_(0, epsilon)
w2 = Tensor(nb_classes, nb_hidden).normal_(0, epsilon)
b2 = Tensor(nb_classes).normal_(0, epsilon)

dl_dw1 = Tensor(w1.size())
dl_db1 = Tensor(b1.size())
dl_dw2 = Tensor(w2.size())
dl_db2 = Tensor(b2.size())
# Out:
# * Using MNIST
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# ** Reduce the data-set (use --full for the full thing)
# ** Use 1000 train and 1000 test samples

# %%
for k in range(0, 1000):

    # Back-prop

    acc_loss = 0
    nb_train_errors = 0

    dl_dw1.zero_()
    dl_db1.zero_()
    dl_dw2.zero_()
    dl_db2.zero_()

    for n in range(0, nb_train_samples):
        x0, s1, x1, s2, x2 = forward_pass(w1, b1, w2, b2, train_input[n])

        pred = x2.max(0)[1][0]
        if train_target[n, pred] < 0: nb_train_errors = nb_train_errors + 1
        acc_loss = acc_loss + loss(x2, train_target[n])

        backward_pass(w1, b1, w2, b2,
                      train_target[n],
                      x0, s1, x1, s2, x2,
                      dl_dw1, dl_db1, dl_dw2, dl_db2)

    # Gradient step

    w1 = w1 - eta * dl_dw1
    b1 = b1 - eta * dl_db1
    w2 = w2 - eta * dl_dw2
    b2 = b2 - eta * dl_db2

    # Test error

    nb_test_errors = 0

    for n in range(0, test_input.size(0)):
        _, _, _, _, x2 = forward_pass(w1, b1, w2, b2, test_input[n])

        pred = x2.max(0)[1][0]
        if test_target[n, pred] < 0: nb_test_errors = nb_test_errors + 1

    print('{:d} acc_train_loss {:.02f} acc_train_error {:.02f}% test_error {:.02f}%'
          .format(k,
                  acc_loss,
                  (100 * nb_train_errors) / train_input.size(0),
                  (100 * nb_test_errors) / test_input.size(0)))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# 0 acc_train_loss 10000.00 acc_train_error 90.30% test_error 90.10%
# 1 acc_train_loss 7712.08 acc_train_error 88.30% test_error 90.10%
# 2 acc_train_loss 6327.60 acc_train_error 88.30% test_error 90.10%
# 3 acc_train_loss 5499.01 acc_train_error 88.30% test_error 90.10%
# 4 acc_train_loss 4982.97 acc_train_error 88.30% test_error 90.10%
# 5 acc_train_loss 4638.62 acc_train_error 88.30% test_error 90.10%
# 6 acc_train_loss 4350.50 acc_train_error 88.30% test_error 90.10%
# 7 acc_train_loss 3952.47 acc_train_error 88.30% test_error 90.10%
# 8 acc_train_loss 3649.57 acc_train_error 88.30% test_error 90.10%
# 9 acc_train_loss 3610.92 acc_train_error 88.30% test_error 90.10%
# 10 acc_train_loss 3605.49 acc_train_error 88.30% test_error 90.10%
# 11 acc_train_loss 3603.86 acc_train_error 88.30% test_error 90.10%
# 12 acc_train_loss 3603.02 acc_train_error 88.40% test_error 90.10%
# 13 acc_train_loss 3602.42 acc_train_error 88.40% test_error 90.10%
# 14 acc_train_loss 3601.89 acc_train_error 88.40% test_error 90.20%
# 15 acc_train_loss 3601.37 acc_train_error 88.50% test_error 90.00%
# 16 acc_train_loss 3600.84 acc_train_error 88.50% test_error 89.70%
# 17 acc_train_loss 3600.27 acc_train_error 88.40% test_error 88.90%
# 18 acc_train_loss 3599.62 acc_train_error 88.20% test_error 87.50%
# 19 acc_train_loss 3598.84 acc_train_error 87.50% test_error 86.40%
# 20 acc_train_loss 3597.89 acc_train_error 86.20% test_error 84.60%
# 21 acc_train_loss 3596.65 acc_train_error 84.90% test_error 83.10%
# 22 acc_train_loss 3595.00 acc_train_error 82.00% test_error 81.90%
# 23 acc_train_loss 3592.73 acc_train_error 81.70% test_error 83.00%
# 24 acc_train_loss 3589.50 acc_train_error 81.60% test_error 83.90%
# 25 acc_train_loss 3584.77 acc_train_error 82.90% test_error 85.30%
# 26 acc_train_loss 3577.68 acc_train_error 84.60% test_error 83.00%
# 27 acc_train_loss 3566.65 acc_train_error 80.50% test_error 79.90%
# 28 acc_train_loss 3548.89 acc_train_error 78.00% test_error 78.90%
# 29 acc_train_loss 3519.52 acc_train_error 78.40% test_error 79.00%
# 30 acc_train_loss 3471.86 acc_train_error 78.90% test_error 79.00%
# 31 acc_train_loss 3406.04 acc_train_error 78.80% test_error 78.90%
# 32 acc_train_loss 3339.54 acc_train_error 78.90% test_error 78.30%
# 33 acc_train_loss 3287.47 acc_train_error 78.20% test_error 77.20%
# 34 acc_train_loss 3246.26 acc_train_error 77.20% test_error 75.20%
# 35 acc_train_loss 3209.27 acc_train_error 75.30% test_error 74.20%
# 36 acc_train_loss 3173.26 acc_train_error 74.00% test_error 73.40%
# 37 acc_train_loss 3137.39 acc_train_error 72.80% test_error 73.00%
# 38 acc_train_loss 3103.04 acc_train_error 71.60% test_error 71.50%
# 39 acc_train_loss 3074.21 acc_train_error 71.00% test_error 72.20%
# 40 acc_train_loss 3061.94 acc_train_error 70.00% test_error 70.20%
# 41 acc_train_loss 3082.37 acc_train_error 69.50% test_error 74.40%
# 42 acc_train_loss 3219.11 acc_train_error 72.50% test_error 66.90%
# 43 acc_train_loss 3160.73 acc_train_error 65.90% test_error 70.10%
# 44 acc_train_loss 2979.77 acc_train_error 67.30% test_error 65.10%
# 45 acc_train_loss 2882.80 acc_train_error 64.20% test_error 68.10%
# 46 acc_train_loss 2855.50 acc_train_error 65.50% test_error 57.10%
# 47 acc_train_loss 2779.47 acc_train_error 56.40% test_error 65.60%
# 48 acc_train_loss 2751.62 acc_train_error 62.50% test_error 53.10%
# 49 acc_train_loss 2722.86 acc_train_error 52.90% test_error 61.20%
# 50 acc_train_loss 2644.51 acc_train_error 57.10% test_error 53.50%
# 51 acc_train_loss 2630.48 acc_train_error 50.50% test_error 52.60%
# 52 acc_train_loss 2511.56 acc_train_error 49.00% test_error 47.60%
# 53 acc_train_loss 2484.95 acc_train_error 43.90% test_error 49.30%
# 54 acc_train_loss 2383.63 acc_train_error 46.10% test_error 43.60%
# 55 acc_train_loss 2355.89 acc_train_error 40.30% test_error 46.90%
# 56 acc_train_loss 2263.00 acc_train_error 44.70% test_error 41.70%
# 57 acc_train_loss 2223.48 acc_train_error 38.60% test_error 44.00%
# 58 acc_train_loss 2149.79 acc_train_error 39.40% test_error 40.00%
# 59 acc_train_loss 2098.46 acc_train_error 36.60% test_error 40.50%
# 60 acc_train_loss 2049.47 acc_train_error 34.60% test_error 39.30%
# 61 acc_train_loss 1996.16 acc_train_error 36.10% test_error 40.10%
# 62 acc_train_loss 1996.00 acc_train_error 34.20% test_error 40.20%
# 63 acc_train_loss 1963.15 acc_train_error 35.30% test_error 43.00%
# 64 acc_train_loss 2047.41 acc_train_error 36.60% test_error 40.60%
# 65 acc_train_loss 1888.58 acc_train_error 32.30% test_error 34.80%
# 66 acc_train_loss 1833.98 acc_train_error 29.90% test_error 34.50%
# 67 acc_train_loss 1712.53 acc_train_error 24.80% test_error 34.30%
# 68 acc_train_loss 1694.81 acc_train_error 27.80% test_error 33.20%
# 69 acc_train_loss 1644.57 acc_train_error 22.40% test_error 31.60%
# 70 acc_train_loss 1599.93 acc_train_error 24.40% test_error 31.20%
# 71 acc_train_loss 1548.51 acc_train_error 19.90% test_error 28.70%
# 72 acc_train_loss 1485.88 acc_train_error 20.30% test_error 29.50%
# 73 acc_train_loss 1442.45 acc_train_error 16.40% test_error 25.90%
# 74 acc_train_loss 1377.62 acc_train_error 17.50% test_error 27.00%
# 75 acc_train_loss 1346.14 acc_train_error 14.80% test_error 24.20%
# 76 acc_train_loss 1283.29 acc_train_error 15.50% test_error 26.30%
# 77 acc_train_loss 1259.10 acc_train_error 13.00% test_error 23.20%
# 78 acc_train_loss 1199.71 acc_train_error 13.90% test_error 25.40%
# 79 acc_train_loss 1177.95 acc_train_error 12.30% test_error 21.40%
# 80 acc_train_loss 1121.01 acc_train_error 11.70% test_error 25.10%
# 81 acc_train_loss 1097.05 acc_train_error 11.10% test_error 20.50%
# 82 acc_train_loss 1044.28 acc_train_error 11.00% test_error 23.50%
# 83 acc_train_loss 1016.50 acc_train_error 10.30% test_error 19.80%
# 84 acc_train_loss 971.66 acc_train_error 10.70% test_error 21.90%
# 85 acc_train_loss 942.63 acc_train_error 9.50% test_error 19.70%
# 86 acc_train_loss 908.41 acc_train_error 10.10% test_error 21.70%
# 87 acc_train_loss 882.54 acc_train_error 8.50% test_error 18.90%
# 88 acc_train_loss 860.08 acc_train_error 9.70% test_error 21.50%
# 89 acc_train_loss 839.29 acc_train_error 8.00% test_error 18.70%
# 90 acc_train_loss 828.25 acc_train_error 9.40% test_error 21.40%
# 91 acc_train_loss 806.50 acc_train_error 7.60% test_error 18.50%
# 92 acc_train_loss 801.06 acc_train_error 9.50% test_error 20.90%
# 93 acc_train_loss 768.01 acc_train_error 7.30% test_error 18.50%
# 94 acc_train_loss 757.28 acc_train_error 8.40% test_error 20.00%
# 95 acc_train_loss 719.27 acc_train_error 6.70% test_error 18.00%
# 96 acc_train_loss 702.55 acc_train_error 7.30% test_error 19.00%
# 97 acc_train_loss 670.80 acc_train_error 6.40% test_error 17.50%
# 98 acc_train_loss 653.48 acc_train_error 6.80% test_error 18.10%
# 99 acc_train_loss 629.67 acc_train_error 5.70% test_error 17.40%
# 100 acc_train_loss 614.22 acc_train_error 6.40% test_error 17.50%
# 101 acc_train_loss 596.04 acc_train_error 5.40% test_error 17.20%
# 102 acc_train_loss 582.64 acc_train_error 6.00% test_error 17.30%
# 103 acc_train_loss 567.93 acc_train_error 5.20% test_error 16.80%
# 104 acc_train_loss 556.19 acc_train_error 5.60% test_error 16.80%
# 105 acc_train_loss 543.69 acc_train_error 5.00% test_error 16.10%
# 106 acc_train_loss 533.30 acc_train_error 5.30% test_error 16.70%
# 107 acc_train_loss 522.42 acc_train_error 4.70% test_error 16.10%
# 108 acc_train_loss 513.20 acc_train_error 5.30% test_error 16.40%
# 109 acc_train_loss 503.72 acc_train_error 4.60% test_error 15.90%
# 110 acc_train_loss 495.58 acc_train_error 5.10% test_error 16.70%
# 111 acc_train_loss 487.58 acc_train_error 4.40% test_error 16.20%
# 112 acc_train_loss 480.35 acc_train_error 5.00% test_error 16.60%
# 113 acc_train_loss 474.06 acc_train_error 4.30% test_error 16.00%
# 114 acc_train_loss 467.24 acc_train_error 4.90% test_error 16.80%
# 115 acc_train_loss 462.78 acc_train_error 4.40% test_error 16.40%
# 116 acc_train_loss 455.46 acc_train_error 4.60% test_error 16.90%
# 117 acc_train_loss 452.34 acc_train_error 4.10% test_error 16.40%
# 118 acc_train_loss 443.60 acc_train_error 4.50% test_error 16.70%
# 119 acc_train_loss 440.70 acc_train_error 4.00% test_error 16.40%
# 120 acc_train_loss 430.52 acc_train_error 4.50% test_error 16.60%
# 121 acc_train_loss 426.78 acc_train_error 4.00% test_error 16.20%
# 122 acc_train_loss 416.11 acc_train_error 4.30% test_error 16.50%
# 123 acc_train_loss 411.24 acc_train_error 3.80% test_error 16.10%
# 124 acc_train_loss 401.11 acc_train_error 4.10% test_error 16.60%
# 125 acc_train_loss 395.45 acc_train_error 3.70% test_error 16.10%
# 126 acc_train_loss 386.39 acc_train_error 3.90% test_error 16.70%
# 127 acc_train_loss 380.43 acc_train_error 3.60% test_error 16.30%
# 128 acc_train_loss 372.51 acc_train_error 3.50% test_error 16.70%
# 129 acc_train_loss 366.60 acc_train_error 3.50% test_error 16.10%
# 130 acc_train_loss 359.67 acc_train_error 3.30% test_error 16.60%
# 131 acc_train_loss 354.00 acc_train_error 3.30% test_error 15.90%
# 132 acc_train_loss 347.86 acc_train_error 3.20% test_error 16.40%
# 133 acc_train_loss 342.50 acc_train_error 3.00% test_error 16.00%
# 134 acc_train_loss 336.95 acc_train_error 3.10% test_error 16.20%
# 135 acc_train_loss 331.90 acc_train_error 2.80% test_error 15.90%
# 136 acc_train_loss 326.82 acc_train_error 3.00% test_error 16.40%
# 137 acc_train_loss 322.07 acc_train_error 2.80% test_error 15.70%
# 138 acc_train_loss 317.35 acc_train_error 2.60% test_error 16.20%
# 139 acc_train_loss 312.86 acc_train_error 2.60% test_error 15.40%
# 140 acc_train_loss 308.45 acc_train_error 2.40% test_error 16.00%
# 141 acc_train_loss 304.20 acc_train_error 2.50% test_error 15.40%
# 142 acc_train_loss 300.04 acc_train_error 2.40% test_error 16.00%
# 143 acc_train_loss 296.00 acc_train_error 2.40% test_error 15.40%
# 144 acc_train_loss 292.06 acc_train_error 2.40% test_error 15.60%
# 145 acc_train_loss 288.22 acc_train_error 2.40% test_error 15.60%
# 146 acc_train_loss 284.47 acc_train_error 2.40% test_error 15.70%
# 147 acc_train_loss 280.81 acc_train_error 2.40% test_error 15.60%
# 148 acc_train_loss 277.23 acc_train_error 2.40% test_error 15.70%
# 149 acc_train_loss 273.73 acc_train_error 2.30% test_error 15.90%
# 150 acc_train_loss 270.31 acc_train_error 2.30% test_error 15.70%
# 151 acc_train_loss 266.96 acc_train_error 2.30% test_error 15.80%
# 152 acc_train_loss 263.69 acc_train_error 2.20% test_error 15.70%
# 153 acc_train_loss 260.48 acc_train_error 2.10% test_error 15.70%
# 154 acc_train_loss 257.34 acc_train_error 2.10% test_error 15.70%
# 155 acc_train_loss 254.27 acc_train_error 2.00% test_error 15.70%
# 156 acc_train_loss 251.26 acc_train_error 2.00% test_error 15.70%
# 157 acc_train_loss 248.32 acc_train_error 2.00% test_error 15.70%
# 158 acc_train_loss 245.43 acc_train_error 2.00% test_error 15.70%
# 159 acc_train_loss 242.61 acc_train_error 2.00% test_error 15.60%
# 160 acc_train_loss 239.84 acc_train_error 1.90% test_error 15.60%
# 161 acc_train_loss 237.14 acc_train_error 1.90% test_error 15.40%
# 162 acc_train_loss 234.48 acc_train_error 1.90% test_error 15.40%
# 163 acc_train_loss 231.89 acc_train_error 1.90% test_error 15.40%
# 164 acc_train_loss 229.35 acc_train_error 1.90% test_error 15.40%
# 165 acc_train_loss 226.86 acc_train_error 1.90% test_error 15.50%
# 166 acc_train_loss 224.42 acc_train_error 1.80% test_error 15.50%
# 167 acc_train_loss 222.03 acc_train_error 1.80% test_error 15.50%
# 168 acc_train_loss 219.69 acc_train_error 1.80% test_error 15.50%
# 169 acc_train_loss 217.39 acc_train_error 1.80% test_error 15.50%
# 170 acc_train_loss 215.15 acc_train_error 1.80% test_error 15.40%
# 171 acc_train_loss 212.95 acc_train_error 1.80% test_error 15.40%
# 172 acc_train_loss 210.79 acc_train_error 1.80% test_error 15.30%
# 173 acc_train_loss 208.67 acc_train_error 1.80% test_error 15.20%
# 174 acc_train_loss 206.60 acc_train_error 1.80% test_error 15.20%
# 175 acc_train_loss 204.57 acc_train_error 1.80% test_error 15.20%
# 176 acc_train_loss 202.57 acc_train_error 1.80% test_error 15.20%
# 177 acc_train_loss 200.62 acc_train_error 1.70% test_error 15.20%
# 178 acc_train_loss 198.70 acc_train_error 1.70% test_error 15.20%
# 179 acc_train_loss 196.82 acc_train_error 1.70% test_error 15.20%
# 180 acc_train_loss 194.97 acc_train_error 1.70% test_error 15.20%
# 181 acc_train_loss 193.16 acc_train_error 1.70% test_error 15.10%
# 182 acc_train_loss 191.39 acc_train_error 1.70% test_error 15.10%
# 183 acc_train_loss 189.65 acc_train_error 1.70% test_error 15.10%
# 184 acc_train_loss 187.94 acc_train_error 1.70% test_error 15.00%
# 185 acc_train_loss 186.26 acc_train_error 1.70% test_error 15.00%
# 186 acc_train_loss 184.62 acc_train_error 1.70% test_error 15.00%
# 187 acc_train_loss 183.01 acc_train_error 1.70% test_error 15.00%
# 188 acc_train_loss 181.42 acc_train_error 1.70% test_error 15.00%
# 189 acc_train_loss 179.87 acc_train_error 1.70% test_error 15.10%
# 190 acc_train_loss 178.34 acc_train_error 1.70% test_error 15.00%
# 191 acc_train_loss 176.85 acc_train_error 1.70% test_error 15.00%
# 192 acc_train_loss 175.38 acc_train_error 1.70% test_error 15.00%
# 193 acc_train_loss 173.94 acc_train_error 1.70% test_error 15.00%
# 194 acc_train_loss 172.52 acc_train_error 1.70% test_error 15.00%
# 195 acc_train_loss 171.13 acc_train_error 1.70% test_error 15.00%
# 196 acc_train_loss 169.76 acc_train_error 1.70% test_error 15.00%
# 197 acc_train_loss 168.42 acc_train_error 1.70% test_error 15.00%
# 198 acc_train_loss 167.10 acc_train_error 1.70% test_error 15.00%
# 199 acc_train_loss 165.80 acc_train_error 1.70% test_error 15.00%
# 200 acc_train_loss 164.53 acc_train_error 1.70% test_error 15.00%
# 201 acc_train_loss 163.28 acc_train_error 1.70% test_error 14.80%
# 202 acc_train_loss 162.04 acc_train_error 1.70% test_error 14.80%
# 203 acc_train_loss 160.83 acc_train_error 1.70% test_error 14.70%
# 204 acc_train_loss 159.64 acc_train_error 1.70% test_error 14.70%
# 205 acc_train_loss 158.46 acc_train_error 1.70% test_error 14.70%
# 206 acc_train_loss 157.31 acc_train_error 1.70% test_error 14.70%
# 207 acc_train_loss 156.17 acc_train_error 1.70% test_error 14.70%
# 208 acc_train_loss 155.05 acc_train_error 1.70% test_error 14.70%
# 209 acc_train_loss 153.94 acc_train_error 1.70% test_error 14.70%
# 210 acc_train_loss 152.85 acc_train_error 1.70% test_error 14.70%
# 211 acc_train_loss 151.78 acc_train_error 1.70% test_error 14.70%
# 212 acc_train_loss 150.73 acc_train_error 1.70% test_error 14.70%
# 213 acc_train_loss 149.68 acc_train_error 1.70% test_error 14.70%
# 214 acc_train_loss 148.66 acc_train_error 1.60% test_error 14.70%
# 215 acc_train_loss 147.65 acc_train_error 1.60% test_error 14.80%
# 216 acc_train_loss 146.65 acc_train_error 1.60% test_error 14.80%
# 217 acc_train_loss 145.66 acc_train_error 1.60% test_error 14.90%
# 218 acc_train_loss 144.69 acc_train_error 1.60% test_error 14.90%
# 219 acc_train_loss 143.73 acc_train_error 1.60% test_error 15.00%
# 220 acc_train_loss 142.78 acc_train_error 1.60% test_error 15.00%
# 221 acc_train_loss 141.84 acc_train_error 1.60% test_error 15.00%
# 222 acc_train_loss 140.92 acc_train_error 1.60% test_error 15.00%
# 223 acc_train_loss 140.00 acc_train_error 1.60% test_error 15.00%
# 224 acc_train_loss 139.09 acc_train_error 1.50% test_error 15.00%
# 225 acc_train_loss 138.19 acc_train_error 1.50% test_error 15.00%
# 226 acc_train_loss 137.30 acc_train_error 1.50% test_error 15.00%
# 227 acc_train_loss 136.42 acc_train_error 1.50% test_error 15.00%
# 228 acc_train_loss 135.54 acc_train_error 1.50% test_error 15.00%
# 229 acc_train_loss 134.67 acc_train_error 1.50% test_error 15.00%
# 230 acc_train_loss 133.80 acc_train_error 1.40% test_error 15.00%
# 231 acc_train_loss 132.94 acc_train_error 1.40% test_error 15.00%
# 232 acc_train_loss 132.09 acc_train_error 1.40% test_error 15.00%
# 233 acc_train_loss 131.24 acc_train_error 1.40% test_error 15.00%
# 234 acc_train_loss 130.40 acc_train_error 1.40% test_error 15.00%
# 235 acc_train_loss 129.57 acc_train_error 1.40% test_error 15.10%
# 236 acc_train_loss 128.74 acc_train_error 1.40% test_error 15.00%
# 237 acc_train_loss 127.93 acc_train_error 1.40% test_error 15.00%
# 238 acc_train_loss 127.12 acc_train_error 1.40% test_error 15.00%
# 239 acc_train_loss 126.33 acc_train_error 1.40% test_error 15.00%
# 240 acc_train_loss 125.54 acc_train_error 1.40% test_error 15.00%
# 241 acc_train_loss 124.77 acc_train_error 1.30% test_error 15.00%
# 242 acc_train_loss 124.02 acc_train_error 1.30% test_error 15.00%
# 243 acc_train_loss 123.27 acc_train_error 1.30% test_error 15.00%
# 244 acc_train_loss 122.54 acc_train_error 1.30% test_error 15.00%
# 245 acc_train_loss 121.81 acc_train_error 1.30% test_error 15.00%
# 246 acc_train_loss 121.10 acc_train_error 1.30% test_error 15.00%
# 247 acc_train_loss 120.40 acc_train_error 1.30% test_error 15.00%
# 248 acc_train_loss 119.71 acc_train_error 1.30% test_error 15.00%
# 249 acc_train_loss 119.03 acc_train_error 1.30% test_error 15.10%
# 250 acc_train_loss 118.36 acc_train_error 1.30% test_error 15.10%
# 251 acc_train_loss 117.70 acc_train_error 1.30% test_error 15.10%
# 252 acc_train_loss 117.05 acc_train_error 1.30% test_error 15.20%
# 253 acc_train_loss 116.40 acc_train_error 1.30% test_error 15.20%
# 254 acc_train_loss 115.77 acc_train_error 1.30% test_error 15.20%
# 255 acc_train_loss 115.15 acc_train_error 1.30% test_error 15.30%
# 256 acc_train_loss 114.53 acc_train_error 1.30% test_error 15.30%
# 257 acc_train_loss 113.92 acc_train_error 1.30% test_error 15.30%
# 258 acc_train_loss 113.32 acc_train_error 1.30% test_error 15.30%
# 259 acc_train_loss 112.73 acc_train_error 1.30% test_error 15.30%
# 260 acc_train_loss 112.15 acc_train_error 1.30% test_error 15.30%
# 261 acc_train_loss 111.58 acc_train_error 1.30% test_error 15.30%
# 262 acc_train_loss 111.01 acc_train_error 1.30% test_error 15.30%
# 263 acc_train_loss 110.45 acc_train_error 1.30% test_error 15.30%
# 264 acc_train_loss 109.91 acc_train_error 1.30% test_error 15.20%
# 265 acc_train_loss 109.36 acc_train_error 1.30% test_error 15.20%
# 266 acc_train_loss 108.83 acc_train_error 1.30% test_error 15.20%
# 267 acc_train_loss 108.31 acc_train_error 1.30% test_error 15.20%
# 268 acc_train_loss 107.79 acc_train_error 1.30% test_error 15.20%
# 269 acc_train_loss 107.28 acc_train_error 1.30% test_error 15.20%
# 270 acc_train_loss 106.78 acc_train_error 1.30% test_error 15.20%
# 271 acc_train_loss 106.28 acc_train_error 1.30% test_error 15.20%
# 272 acc_train_loss 105.79 acc_train_error 1.30% test_error 15.20%
# 273 acc_train_loss 105.31 acc_train_error 1.30% test_error 15.20%
# 274 acc_train_loss 104.84 acc_train_error 1.30% test_error 15.20%
# 275 acc_train_loss 104.37 acc_train_error 1.30% test_error 15.20%
# 276 acc_train_loss 103.91 acc_train_error 1.30% test_error 15.20%
# 277 acc_train_loss 103.45 acc_train_error 1.20% test_error 15.20%
# 278 acc_train_loss 103.00 acc_train_error 1.20% test_error 15.20%
# 279 acc_train_loss 102.56 acc_train_error 1.20% test_error 15.20%
# 280 acc_train_loss 102.12 acc_train_error 1.20% test_error 15.20%
# 281 acc_train_loss 101.69 acc_train_error 1.20% test_error 15.10%
# 282 acc_train_loss 101.27 acc_train_error 1.20% test_error 15.10%
# 283 acc_train_loss 100.85 acc_train_error 1.20% test_error 15.10%
# 284 acc_train_loss 100.43 acc_train_error 1.20% test_error 15.10%
# 285 acc_train_loss 100.02 acc_train_error 1.20% test_error 15.10%
# 286 acc_train_loss 99.62 acc_train_error 1.20% test_error 15.10%
# 287 acc_train_loss 99.22 acc_train_error 1.20% test_error 15.10%
# 288 acc_train_loss 98.83 acc_train_error 1.20% test_error 15.10%
# 289 acc_train_loss 98.44 acc_train_error 1.20% test_error 15.10%
# 290 acc_train_loss 98.06 acc_train_error 1.20% test_error 15.20%
# 291 acc_train_loss 97.68 acc_train_error 1.20% test_error 15.20%
# 292 acc_train_loss 97.30 acc_train_error 1.20% test_error 15.20%
# 293 acc_train_loss 96.93 acc_train_error 1.20% test_error 15.20%
# 294 acc_train_loss 96.57 acc_train_error 1.20% test_error 15.20%
# 295 acc_train_loss 96.20 acc_train_error 1.20% test_error 15.20%
# 296 acc_train_loss 95.85 acc_train_error 1.20% test_error 15.20%
# 297 acc_train_loss 95.49 acc_train_error 1.20% test_error 15.20%
# 298 acc_train_loss 95.14 acc_train_error 1.20% test_error 15.20%
# 299 acc_train_loss 94.80 acc_train_error 1.20% test_error 15.20%
# 300 acc_train_loss 94.45 acc_train_error 1.20% test_error 15.20%
# 301 acc_train_loss 94.12 acc_train_error 1.20% test_error 15.10%
# 302 acc_train_loss 93.78 acc_train_error 1.20% test_error 15.10%
# 303 acc_train_loss 93.45 acc_train_error 1.20% test_error 15.10%
# 304 acc_train_loss 93.12 acc_train_error 1.20% test_error 15.10%
# 305 acc_train_loss 92.80 acc_train_error 1.20% test_error 15.10%
# 306 acc_train_loss 92.47 acc_train_error 1.20% test_error 15.10%
# 307 acc_train_loss 92.15 acc_train_error 1.20% test_error 15.10%
# 308 acc_train_loss 91.84 acc_train_error 1.20% test_error 15.10%
# 309 acc_train_loss 91.53 acc_train_error 1.20% test_error 15.10%
# 310 acc_train_loss 91.22 acc_train_error 1.20% test_error 15.10%
# 311 acc_train_loss 90.91 acc_train_error 1.20% test_error 15.10%
# 312 acc_train_loss 90.60 acc_train_error 1.20% test_error 15.10%
# 313 acc_train_loss 90.30 acc_train_error 1.20% test_error 15.10%
# 314 acc_train_loss 90.00 acc_train_error 1.20% test_error 15.10%
# 315 acc_train_loss 89.70 acc_train_error 1.20% test_error 15.10%
# 316 acc_train_loss 89.41 acc_train_error 1.20% test_error 15.10%
# 317 acc_train_loss 89.11 acc_train_error 1.20% test_error 15.10%
# 318 acc_train_loss 88.82 acc_train_error 1.20% test_error 15.10%
# 319 acc_train_loss 88.53 acc_train_error 1.20% test_error 15.10%
# 320 acc_train_loss 88.24 acc_train_error 1.20% test_error 15.10%
# 321 acc_train_loss 87.95 acc_train_error 1.20% test_error 15.10%
# 322 acc_train_loss 87.66 acc_train_error 1.20% test_error 15.10%
# 323 acc_train_loss 87.38 acc_train_error 1.20% test_error 15.10%
# 324 acc_train_loss 87.09 acc_train_error 1.20% test_error 15.10%
# 325 acc_train_loss 86.81 acc_train_error 1.20% test_error 15.10%
# 326 acc_train_loss 86.52 acc_train_error 1.20% test_error 15.10%
# 327 acc_train_loss 86.23 acc_train_error 1.20% test_error 15.00%
# 328 acc_train_loss 85.94 acc_train_error 1.10% test_error 15.00%
# 329 acc_train_loss 85.65 acc_train_error 1.10% test_error 15.00%
# 330 acc_train_loss 85.36 acc_train_error 1.10% test_error 14.90%
# 331 acc_train_loss 85.07 acc_train_error 1.10% test_error 14.90%
# 332 acc_train_loss 84.78 acc_train_error 1.10% test_error 14.90%
# 333 acc_train_loss 84.48 acc_train_error 1.10% test_error 14.90%
# 334 acc_train_loss 84.18 acc_train_error 1.10% test_error 14.80%
# 335 acc_train_loss 83.88 acc_train_error 1.10% test_error 14.80%
# 336 acc_train_loss 83.58 acc_train_error 1.10% test_error 14.90%
# 337 acc_train_loss 83.28 acc_train_error 1.10% test_error 14.90%
# 338 acc_train_loss 82.98 acc_train_error 1.10% test_error 14.90%
# 339 acc_train_loss 82.68 acc_train_error 1.10% test_error 14.90%
# 340 acc_train_loss 82.38 acc_train_error 1.10% test_error 14.90%
# 341 acc_train_loss 82.08 acc_train_error 1.10% test_error 14.90%
# 342 acc_train_loss 81.79 acc_train_error 1.10% test_error 14.90%
# 343 acc_train_loss 81.51 acc_train_error 1.10% test_error 14.90%
# 344 acc_train_loss 81.22 acc_train_error 1.10% test_error 14.90%
# 345 acc_train_loss 80.95 acc_train_error 1.10% test_error 14.90%
# 346 acc_train_loss 80.68 acc_train_error 1.10% test_error 14.90%
# 347 acc_train_loss 80.41 acc_train_error 1.10% test_error 14.80%
# 348 acc_train_loss 80.15 acc_train_error 1.10% test_error 14.80%
# 349 acc_train_loss 79.90 acc_train_error 1.10% test_error 14.80%
# 350 acc_train_loss 79.65 acc_train_error 1.10% test_error 14.80%
# 351 acc_train_loss 79.41 acc_train_error 1.10% test_error 14.80%
# 352 acc_train_loss 79.17 acc_train_error 1.10% test_error 14.80%
# 353 acc_train_loss 78.93 acc_train_error 1.10% test_error 14.80%
# 354 acc_train_loss 78.70 acc_train_error 1.10% test_error 14.80%
# 355 acc_train_loss 78.48 acc_train_error 1.10% test_error 14.80%
# 356 acc_train_loss 78.25 acc_train_error 1.10% test_error 14.80%
# 357 acc_train_loss 78.04 acc_train_error 1.10% test_error 14.70%
# 358 acc_train_loss 77.82 acc_train_error 1.10% test_error 14.70%
# 359 acc_train_loss 77.61 acc_train_error 1.10% test_error 14.70%
# 360 acc_train_loss 77.40 acc_train_error 1.10% test_error 14.80%
# 361 acc_train_loss 77.20 acc_train_error 1.10% test_error 14.80%
# 362 acc_train_loss 76.99 acc_train_error 1.10% test_error 14.80%
# 363 acc_train_loss 76.79 acc_train_error 1.10% test_error 14.80%
# 364 acc_train_loss 76.59 acc_train_error 1.10% test_error 14.80%
# 365 acc_train_loss 76.40 acc_train_error 1.10% test_error 14.80%
# 366 acc_train_loss 76.21 acc_train_error 1.10% test_error 14.80%
# 367 acc_train_loss 76.02 acc_train_error 1.10% test_error 14.80%
# 368 acc_train_loss 75.83 acc_train_error 1.10% test_error 14.80%
# 369 acc_train_loss 75.64 acc_train_error 1.10% test_error 14.80%
# 370 acc_train_loss 75.46 acc_train_error 1.10% test_error 14.80%
# 371 acc_train_loss 75.28 acc_train_error 1.10% test_error 14.80%
# 372 acc_train_loss 75.10 acc_train_error 1.10% test_error 14.80%
# 373 acc_train_loss 74.92 acc_train_error 1.10% test_error 14.80%
# 374 acc_train_loss 74.74 acc_train_error 1.10% test_error 14.80%
# 375 acc_train_loss 74.57 acc_train_error 1.10% test_error 14.80%
# 376 acc_train_loss 74.40 acc_train_error 1.10% test_error 14.80%
# 377 acc_train_loss 74.23 acc_train_error 1.10% test_error 14.80%
# 378 acc_train_loss 74.06 acc_train_error 1.10% test_error 14.80%
# 379 acc_train_loss 73.89 acc_train_error 1.10% test_error 14.80%
# 380 acc_train_loss 73.73 acc_train_error 1.10% test_error 14.80%
# 381 acc_train_loss 73.56 acc_train_error 1.10% test_error 14.80%
# 382 acc_train_loss 73.40 acc_train_error 1.10% test_error 14.80%
# 383 acc_train_loss 73.24 acc_train_error 1.10% test_error 14.80%
# 384 acc_train_loss 73.08 acc_train_error 1.10% test_error 14.80%
# 385 acc_train_loss 72.93 acc_train_error 1.10% test_error 14.80%
# 386 acc_train_loss 72.77 acc_train_error 1.10% test_error 14.80%
# 387 acc_train_loss 72.62 acc_train_error 1.10% test_error 14.80%
# 388 acc_train_loss 72.46 acc_train_error 1.10% test_error 14.80%
# 389 acc_train_loss 72.31 acc_train_error 1.10% test_error 14.80%
# 390 acc_train_loss 72.16 acc_train_error 1.10% test_error 14.80%
# 391 acc_train_loss 72.02 acc_train_error 1.10% test_error 14.80%
# 392 acc_train_loss 71.87 acc_train_error 1.10% test_error 14.80%
# 393 acc_train_loss 71.72 acc_train_error 1.10% test_error 14.80%
# 394 acc_train_loss 71.58 acc_train_error 1.10% test_error 14.80%
# 395 acc_train_loss 71.43 acc_train_error 1.10% test_error 14.80%
# 396 acc_train_loss 71.29 acc_train_error 1.10% test_error 14.80%
# 397 acc_train_loss 71.15 acc_train_error 1.10% test_error 14.80%
# 398 acc_train_loss 71.01 acc_train_error 1.10% test_error 14.80%
# 399 acc_train_loss 70.87 acc_train_error 1.10% test_error 14.80%
# 400 acc_train_loss 70.74 acc_train_error 1.10% test_error 14.80%
# 401 acc_train_loss 70.60 acc_train_error 1.10% test_error 14.80%
# 402 acc_train_loss 70.46 acc_train_error 1.10% test_error 14.80%
# 403 acc_train_loss 70.33 acc_train_error 1.10% test_error 14.80%
# 404 acc_train_loss 70.20 acc_train_error 1.10% test_error 14.80%
# 405 acc_train_loss 70.06 acc_train_error 1.10% test_error 14.80%
# 406 acc_train_loss 69.93 acc_train_error 1.10% test_error 14.80%
# 407 acc_train_loss 69.80 acc_train_error 1.10% test_error 14.80%
# 408 acc_train_loss 69.67 acc_train_error 1.10% test_error 14.80%
# 409 acc_train_loss 69.55 acc_train_error 1.10% test_error 14.80%
# 410 acc_train_loss 69.42 acc_train_error 1.10% test_error 14.80%
# 411 acc_train_loss 69.29 acc_train_error 1.10% test_error 14.80%
# 412 acc_train_loss 69.17 acc_train_error 1.10% test_error 14.80%
# 413 acc_train_loss 69.04 acc_train_error 1.10% test_error 14.90%
# 414 acc_train_loss 68.92 acc_train_error 1.10% test_error 14.90%
# 415 acc_train_loss 68.80 acc_train_error 1.10% test_error 14.90%
# 416 acc_train_loss 68.68 acc_train_error 1.10% test_error 14.90%
# 417 acc_train_loss 68.55 acc_train_error 1.10% test_error 14.90%
# 418 acc_train_loss 68.43 acc_train_error 1.10% test_error 14.90%
# 419 acc_train_loss 68.31 acc_train_error 1.10% test_error 14.90%
# 420 acc_train_loss 68.20 acc_train_error 1.10% test_error 14.90%
# 421 acc_train_loss 68.08 acc_train_error 1.10% test_error 15.00%
# 422 acc_train_loss 67.96 acc_train_error 1.10% test_error 14.90%
# 423 acc_train_loss 67.84 acc_train_error 1.10% test_error 14.90%
# 424 acc_train_loss 67.73 acc_train_error 1.10% test_error 14.90%
# 425 acc_train_loss 67.61 acc_train_error 1.10% test_error 14.90%
# 426 acc_train_loss 67.50 acc_train_error 1.10% test_error 14.90%
# 427 acc_train_loss 67.38 acc_train_error 1.10% test_error 14.90%
# 428 acc_train_loss 67.27 acc_train_error 1.10% test_error 14.90%
# 429 acc_train_loss 67.15 acc_train_error 1.10% test_error 14.90%
# 430 acc_train_loss 67.04 acc_train_error 1.10% test_error 14.90%
# 431 acc_train_loss 66.93 acc_train_error 1.10% test_error 14.90%
# 432 acc_train_loss 66.81 acc_train_error 1.10% test_error 14.90%
# 433 acc_train_loss 66.70 acc_train_error 1.10% test_error 14.90%
# 434 acc_train_loss 66.59 acc_train_error 1.10% test_error 14.90%
# 435 acc_train_loss 66.48 acc_train_error 1.10% test_error 14.90%
# 436 acc_train_loss 66.37 acc_train_error 1.10% test_error 14.90%
# 437 acc_train_loss 66.26 acc_train_error 1.10% test_error 14.90%
# 438 acc_train_loss 66.14 acc_train_error 1.10% test_error 14.90%
# 439 acc_train_loss 66.03 acc_train_error 1.10% test_error 14.90%
# 440 acc_train_loss 65.92 acc_train_error 1.10% test_error 14.90%
# 441 acc_train_loss 65.81 acc_train_error 1.10% test_error 14.90%
# 442 acc_train_loss 65.70 acc_train_error 1.10% test_error 14.90%
# 443 acc_train_loss 65.59 acc_train_error 1.10% test_error 14.90%
# 444 acc_train_loss 65.48 acc_train_error 1.10% test_error 14.90%
# 445 acc_train_loss 65.36 acc_train_error 1.10% test_error 14.90%
# 446 acc_train_loss 65.25 acc_train_error 1.10% test_error 14.90%
# 447 acc_train_loss 65.14 acc_train_error 1.10% test_error 14.90%
# 448 acc_train_loss 65.02 acc_train_error 1.10% test_error 14.90%
# 449 acc_train_loss 64.91 acc_train_error 1.10% test_error 14.90%
# 450 acc_train_loss 64.79 acc_train_error 1.10% test_error 14.90%
# 451 acc_train_loss 64.68 acc_train_error 1.10% test_error 14.90%
# 452 acc_train_loss 64.56 acc_train_error 1.10% test_error 14.90%
# 453 acc_train_loss 64.44 acc_train_error 1.10% test_error 14.90%
# 454 acc_train_loss 64.32 acc_train_error 1.10% test_error 14.90%
# 455 acc_train_loss 64.19 acc_train_error 1.00% test_error 14.90%
# 456 acc_train_loss 64.07 acc_train_error 1.00% test_error 14.90%
# 457 acc_train_loss 63.94 acc_train_error 1.00% test_error 14.90%
# 458 acc_train_loss 63.81 acc_train_error 1.00% test_error 14.90%
# 459 acc_train_loss 63.68 acc_train_error 1.00% test_error 14.90%
# 460 acc_train_loss 63.55 acc_train_error 1.00% test_error 14.90%
# 461 acc_train_loss 63.41 acc_train_error 1.00% test_error 14.90%
# 462 acc_train_loss 63.27 acc_train_error 1.00% test_error 14.90%
# 463 acc_train_loss 63.13 acc_train_error 1.00% test_error 14.90%
# 464 acc_train_loss 62.99 acc_train_error 1.00% test_error 14.90%
# 465 acc_train_loss 62.84 acc_train_error 1.00% test_error 14.90%
# 466 acc_train_loss 62.69 acc_train_error 1.00% test_error 14.90%
# 467 acc_train_loss 62.54 acc_train_error 1.00% test_error 15.00%
# 468 acc_train_loss 62.39 acc_train_error 1.00% test_error 15.00%
# 469 acc_train_loss 62.23 acc_train_error 1.00% test_error 15.00%
# 470 acc_train_loss 62.07 acc_train_error 1.00% test_error 15.00%
# 471 acc_train_loss 61.92 acc_train_error 1.00% test_error 15.00%
# 472 acc_train_loss 61.76 acc_train_error 1.00% test_error 15.00%
# 473 acc_train_loss 61.61 acc_train_error 1.00% test_error 15.00%
# 474 acc_train_loss 61.45 acc_train_error 1.00% test_error 15.00%
# 475 acc_train_loss 61.30 acc_train_error 1.00% test_error 15.00%
# 476 acc_train_loss 61.16 acc_train_error 1.00% test_error 15.00%
# 477 acc_train_loss 61.01 acc_train_error 1.00% test_error 15.00%
# 478 acc_train_loss 60.88 acc_train_error 1.00% test_error 15.00%
# 479 acc_train_loss 60.74 acc_train_error 1.00% test_error 15.00%
# 480 acc_train_loss 60.61 acc_train_error 1.00% test_error 15.00%
# 481 acc_train_loss 60.49 acc_train_error 1.00% test_error 15.00%
# 482 acc_train_loss 60.37 acc_train_error 1.00% test_error 14.90%
# 483 acc_train_loss 60.25 acc_train_error 1.00% test_error 14.90%
# 484 acc_train_loss 60.14 acc_train_error 1.00% test_error 14.90%
# 485 acc_train_loss 60.03 acc_train_error 1.00% test_error 15.00%
# 486 acc_train_loss 59.92 acc_train_error 1.00% test_error 15.00%
# 487 acc_train_loss 59.82 acc_train_error 1.00% test_error 15.00%
# 488 acc_train_loss 59.72 acc_train_error 1.00% test_error 15.00%
# 489 acc_train_loss 59.62 acc_train_error 1.00% test_error 15.00%
# 490 acc_train_loss 59.52 acc_train_error 1.00% test_error 15.00%
# 491 acc_train_loss 59.43 acc_train_error 1.00% test_error 14.90%
# 492 acc_train_loss 59.34 acc_train_error 1.00% test_error 14.90%
# 493 acc_train_loss 59.25 acc_train_error 1.00% test_error 14.90%
# 494 acc_train_loss 59.16 acc_train_error 1.00% test_error 14.90%
# 495 acc_train_loss 59.07 acc_train_error 1.00% test_error 14.90%
# 496 acc_train_loss 58.99 acc_train_error 1.00% test_error 14.90%
# 497 acc_train_loss 58.91 acc_train_error 1.00% test_error 14.90%
# 498 acc_train_loss 58.82 acc_train_error 1.00% test_error 14.90%
# 499 acc_train_loss 58.74 acc_train_error 1.00% test_error 14.90%
# 500 acc_train_loss 58.66 acc_train_error 1.00% test_error 14.90%
# 501 acc_train_loss 58.58 acc_train_error 1.00% test_error 14.90%
# 502 acc_train_loss 58.50 acc_train_error 1.00% test_error 14.90%
# 503 acc_train_loss 58.42 acc_train_error 1.00% test_error 14.90%
# 504 acc_train_loss 58.35 acc_train_error 1.00% test_error 14.90%
# 505 acc_train_loss 58.27 acc_train_error 1.00% test_error 14.90%
# 506 acc_train_loss 58.20 acc_train_error 1.00% test_error 14.90%
# 507 acc_train_loss 58.12 acc_train_error 1.00% test_error 14.90%
# 508 acc_train_loss 58.04 acc_train_error 1.00% test_error 14.90%
# 509 acc_train_loss 57.97 acc_train_error 1.00% test_error 14.90%
# 510 acc_train_loss 57.90 acc_train_error 1.00% test_error 14.90%
# 511 acc_train_loss 57.82 acc_train_error 1.00% test_error 14.90%
# 512 acc_train_loss 57.75 acc_train_error 1.00% test_error 14.90%
# 513 acc_train_loss 57.68 acc_train_error 1.00% test_error 14.90%
# 514 acc_train_loss 57.60 acc_train_error 1.00% test_error 14.90%
# 515 acc_train_loss 57.53 acc_train_error 1.00% test_error 15.00%
# 516 acc_train_loss 57.46 acc_train_error 1.00% test_error 15.00%
# 517 acc_train_loss 57.38 acc_train_error 1.00% test_error 15.10%
# 518 acc_train_loss 57.31 acc_train_error 1.00% test_error 15.20%
# 519 acc_train_loss 57.23 acc_train_error 1.00% test_error 15.20%
# 520 acc_train_loss 57.15 acc_train_error 1.00% test_error 15.20%
# 521 acc_train_loss 57.08 acc_train_error 1.00% test_error 15.20%
# 522 acc_train_loss 57.00 acc_train_error 1.00% test_error 15.20%
# 523 acc_train_loss 56.91 acc_train_error 1.00% test_error 15.10%
# 524 acc_train_loss 56.83 acc_train_error 1.00% test_error 15.10%
# 525 acc_train_loss 56.74 acc_train_error 1.00% test_error 15.10%
# 526 acc_train_loss 56.65 acc_train_error 1.00% test_error 15.10%
# 527 acc_train_loss 56.55 acc_train_error 1.00% test_error 15.10%
# 528 acc_train_loss 56.43 acc_train_error 1.00% test_error 15.10%
# 529 acc_train_loss 56.31 acc_train_error 1.00% test_error 15.10%
# 530 acc_train_loss 56.18 acc_train_error 1.00% test_error 15.10%
# 531 acc_train_loss 56.02 acc_train_error 1.00% test_error 15.10%
# 532 acc_train_loss 55.84 acc_train_error 0.90% test_error 15.10%
# 533 acc_train_loss 55.63 acc_train_error 0.90% test_error 15.10%
# 534 acc_train_loss 55.39 acc_train_error 0.90% test_error 15.10%
# 535 acc_train_loss 55.13 acc_train_error 0.90% test_error 15.10%
# 536 acc_train_loss 54.86 acc_train_error 0.90% test_error 15.10%
# 537 acc_train_loss 54.60 acc_train_error 0.90% test_error 15.10%
# 538 acc_train_loss 54.36 acc_train_error 0.90% test_error 15.10%
# 539 acc_train_loss 54.14 acc_train_error 0.90% test_error 15.10%
# 540 acc_train_loss 53.96 acc_train_error 0.90% test_error 15.10%
# 541 acc_train_loss 53.79 acc_train_error 0.90% test_error 15.10%
# 542 acc_train_loss 53.64 acc_train_error 0.90% test_error 15.10%
# 543 acc_train_loss 53.51 acc_train_error 0.90% test_error 15.10%
# 544 acc_train_loss 53.39 acc_train_error 0.90% test_error 15.10%
# 545 acc_train_loss 53.28 acc_train_error 0.90% test_error 15.10%
# 546 acc_train_loss 53.18 acc_train_error 0.90% test_error 15.10%
# 547 acc_train_loss 53.08 acc_train_error 0.90% test_error 15.10%
# 548 acc_train_loss 52.99 acc_train_error 0.90% test_error 15.10%
# 549 acc_train_loss 52.90 acc_train_error 0.90% test_error 15.00%
# 550 acc_train_loss 52.82 acc_train_error 0.90% test_error 15.00%
# 551 acc_train_loss 52.73 acc_train_error 0.90% test_error 15.00%
# 552 acc_train_loss 52.66 acc_train_error 0.90% test_error 15.00%
# 553 acc_train_loss 52.58 acc_train_error 0.90% test_error 15.00%
# 554 acc_train_loss 52.51 acc_train_error 0.90% test_error 15.00%
# 555 acc_train_loss 52.43 acc_train_error 0.90% test_error 15.00%
# 556 acc_train_loss 52.36 acc_train_error 0.90% test_error 15.00%
# 557 acc_train_loss 52.30 acc_train_error 0.90% test_error 15.00%
# 558 acc_train_loss 52.23 acc_train_error 0.90% test_error 15.00%
# 559 acc_train_loss 52.16 acc_train_error 0.90% test_error 15.00%
# 560 acc_train_loss 52.10 acc_train_error 0.90% test_error 15.00%
# 561 acc_train_loss 52.04 acc_train_error 0.90% test_error 15.00%
# 562 acc_train_loss 51.97 acc_train_error 0.90% test_error 15.00%
# 563 acc_train_loss 51.91 acc_train_error 0.90% test_error 15.00%
# 564 acc_train_loss 51.85 acc_train_error 0.90% test_error 15.00%
# 565 acc_train_loss 51.79 acc_train_error 0.90% test_error 15.00%
# 566 acc_train_loss 51.73 acc_train_error 0.90% test_error 15.00%
# 567 acc_train_loss 51.67 acc_train_error 0.90% test_error 15.00%
# 568 acc_train_loss 51.62 acc_train_error 0.90% test_error 15.00%
# 569 acc_train_loss 51.56 acc_train_error 0.90% test_error 15.00%
# 570 acc_train_loss 51.50 acc_train_error 0.90% test_error 15.00%
# 571 acc_train_loss 51.45 acc_train_error 0.90% test_error 15.00%
# 572 acc_train_loss 51.39 acc_train_error 0.90% test_error 15.00%
# 573 acc_train_loss 51.34 acc_train_error 0.90% test_error 15.00%
# 574 acc_train_loss 51.28 acc_train_error 0.90% test_error 15.00%
# 575 acc_train_loss 51.23 acc_train_error 0.90% test_error 15.00%
# 576 acc_train_loss 51.18 acc_train_error 0.90% test_error 15.00%
# 577 acc_train_loss 51.13 acc_train_error 0.90% test_error 15.00%
# 578 acc_train_loss 51.07 acc_train_error 0.90% test_error 15.00%
# 579 acc_train_loss 51.02 acc_train_error 0.90% test_error 15.00%
# 580 acc_train_loss 50.97 acc_train_error 0.90% test_error 15.10%
# 581 acc_train_loss 50.92 acc_train_error 0.90% test_error 15.10%
# 582 acc_train_loss 50.87 acc_train_error 0.90% test_error 15.10%
# 583 acc_train_loss 50.82 acc_train_error 0.90% test_error 15.10%
# 584 acc_train_loss 50.77 acc_train_error 0.90% test_error 15.10%
# 585 acc_train_loss 50.72 acc_train_error 0.90% test_error 15.10%
# 586 acc_train_loss 50.67 acc_train_error 0.90% test_error 15.10%
# 587 acc_train_loss 50.63 acc_train_error 0.90% test_error 15.10%
# 588 acc_train_loss 50.58 acc_train_error 0.90% test_error 15.10%
# 589 acc_train_loss 50.53 acc_train_error 0.90% test_error 15.10%
# 590 acc_train_loss 50.49 acc_train_error 0.90% test_error 15.10%
# 591 acc_train_loss 50.44 acc_train_error 0.90% test_error 15.10%
# 592 acc_train_loss 50.39 acc_train_error 0.90% test_error 15.10%
# 593 acc_train_loss 50.35 acc_train_error 0.90% test_error 15.10%
# 594 acc_train_loss 50.30 acc_train_error 0.90% test_error 15.10%
# 595 acc_train_loss 50.26 acc_train_error 0.90% test_error 15.10%
# 596 acc_train_loss 50.21 acc_train_error 0.90% test_error 15.10%
# 597 acc_train_loss 50.17 acc_train_error 0.90% test_error 15.10%
# 598 acc_train_loss 50.12 acc_train_error 0.90% test_error 15.10%
# 599 acc_train_loss 50.08 acc_train_error 0.90% test_error 15.10%
# 600 acc_train_loss 50.03 acc_train_error 0.90% test_error 15.10%
# 601 acc_train_loss 49.99 acc_train_error 0.90% test_error 15.10%
# 602 acc_train_loss 49.95 acc_train_error 0.90% test_error 15.10%
# 603 acc_train_loss 49.91 acc_train_error 0.90% test_error 15.10%
# 604 acc_train_loss 49.86 acc_train_error 0.90% test_error 15.10%
# 605 acc_train_loss 49.82 acc_train_error 0.90% test_error 15.10%
# 606 acc_train_loss 49.78 acc_train_error 0.90% test_error 15.10%
# 607 acc_train_loss 49.74 acc_train_error 0.90% test_error 15.10%
# 608 acc_train_loss 49.70 acc_train_error 0.90% test_error 15.10%
# 609 acc_train_loss 49.65 acc_train_error 0.90% test_error 15.10%
# 610 acc_train_loss 49.61 acc_train_error 0.90% test_error 15.10%
# 611 acc_train_loss 49.57 acc_train_error 0.90% test_error 15.10%
# 612 acc_train_loss 49.53 acc_train_error 0.90% test_error 15.10%
# 613 acc_train_loss 49.49 acc_train_error 0.90% test_error 15.10%
# 614 acc_train_loss 49.45 acc_train_error 0.90% test_error 15.10%
# 615 acc_train_loss 49.41 acc_train_error 0.90% test_error 15.10%
# 616 acc_train_loss 49.37 acc_train_error 0.90% test_error 15.10%
# 617 acc_train_loss 49.33 acc_train_error 0.90% test_error 15.10%
# 618 acc_train_loss 49.30 acc_train_error 0.90% test_error 15.10%
# 619 acc_train_loss 49.26 acc_train_error 0.90% test_error 15.10%
# 620 acc_train_loss 49.22 acc_train_error 0.90% test_error 15.10%
# 621 acc_train_loss 49.18 acc_train_error 0.90% test_error 15.10%
# 622 acc_train_loss 49.14 acc_train_error 0.90% test_error 15.10%
# 623 acc_train_loss 49.10 acc_train_error 0.90% test_error 15.10%
# 624 acc_train_loss 49.07 acc_train_error 0.90% test_error 15.10%
# 625 acc_train_loss 49.03 acc_train_error 0.90% test_error 15.10%
# 626 acc_train_loss 48.99 acc_train_error 0.90% test_error 15.10%
# 627 acc_train_loss 48.95 acc_train_error 0.90% test_error 15.10%
# 628 acc_train_loss 48.92 acc_train_error 0.90% test_error 15.10%
# 629 acc_train_loss 48.88 acc_train_error 0.90% test_error 15.10%
# 630 acc_train_loss 48.84 acc_train_error 0.90% test_error 15.10%
# 631 acc_train_loss 48.81 acc_train_error 0.90% test_error 15.10%
# 632 acc_train_loss 48.77 acc_train_error 0.90% test_error 15.10%
# 633 acc_train_loss 48.74 acc_train_error 0.90% test_error 15.10%
# 634 acc_train_loss 48.70 acc_train_error 0.90% test_error 15.10%
# 635 acc_train_loss 48.67 acc_train_error 0.90% test_error 15.10%
# 636 acc_train_loss 48.63 acc_train_error 0.90% test_error 15.10%
# 637 acc_train_loss 48.60 acc_train_error 0.90% test_error 15.10%
# 638 acc_train_loss 48.56 acc_train_error 0.90% test_error 15.10%
# 639 acc_train_loss 48.53 acc_train_error 0.90% test_error 15.10%
# 640 acc_train_loss 48.49 acc_train_error 0.90% test_error 15.10%
# 641 acc_train_loss 48.46 acc_train_error 0.90% test_error 15.10%
# 642 acc_train_loss 48.42 acc_train_error 0.90% test_error 15.10%
# 643 acc_train_loss 48.39 acc_train_error 0.90% test_error 15.10%
# 644 acc_train_loss 48.35 acc_train_error 0.90% test_error 15.10%
# 645 acc_train_loss 48.32 acc_train_error 0.90% test_error 15.10%
# 646 acc_train_loss 48.29 acc_train_error 0.90% test_error 15.10%
# 647 acc_train_loss 48.25 acc_train_error 0.90% test_error 15.10%
# 648 acc_train_loss 48.22 acc_train_error 0.90% test_error 15.10%
# 649 acc_train_loss 48.19 acc_train_error 0.90% test_error 15.10%
# 650 acc_train_loss 48.16 acc_train_error 0.90% test_error 15.10%
# 651 acc_train_loss 48.12 acc_train_error 0.90% test_error 15.10%
# 652 acc_train_loss 48.09 acc_train_error 0.90% test_error 15.10%
# 653 acc_train_loss 48.06 acc_train_error 0.90% test_error 15.10%
# 654 acc_train_loss 48.03 acc_train_error 0.90% test_error 15.10%
# 655 acc_train_loss 47.99 acc_train_error 0.90% test_error 15.10%
# 656 acc_train_loss 47.96 acc_train_error 0.90% test_error 15.10%
# 657 acc_train_loss 47.93 acc_train_error 0.90% test_error 15.10%
# 658 acc_train_loss 47.90 acc_train_error 0.90% test_error 15.10%
# 659 acc_train_loss 47.87 acc_train_error 0.90% test_error 15.10%
# 660 acc_train_loss 47.84 acc_train_error 0.90% test_error 15.10%
# 661 acc_train_loss 47.81 acc_train_error 0.90% test_error 15.10%
# 662 acc_train_loss 47.77 acc_train_error 0.90% test_error 15.10%
# 663 acc_train_loss 47.74 acc_train_error 0.90% test_error 15.10%
# 664 acc_train_loss 47.71 acc_train_error 0.90% test_error 15.10%
# 665 acc_train_loss 47.68 acc_train_error 0.90% test_error 15.10%
# 666 acc_train_loss 47.65 acc_train_error 0.90% test_error 15.00%
# 667 acc_train_loss 47.62 acc_train_error 0.90% test_error 15.00%
# 668 acc_train_loss 47.59 acc_train_error 0.90% test_error 15.00%
# 669 acc_train_loss 47.56 acc_train_error 0.90% test_error 15.00%
# 670 acc_train_loss 47.53 acc_train_error 0.90% test_error 15.00%
# 671 acc_train_loss 47.50 acc_train_error 0.90% test_error 15.00%
# 672 acc_train_loss 47.47 acc_train_error 0.90% test_error 15.00%
# 673 acc_train_loss 47.44 acc_train_error 0.90% test_error 15.00%
# 674 acc_train_loss 47.41 acc_train_error 0.90% test_error 15.00%
# 675 acc_train_loss 47.38 acc_train_error 0.90% test_error 15.00%
# 676 acc_train_loss 47.35 acc_train_error 0.90% test_error 15.00%
# 677 acc_train_loss 47.33 acc_train_error 0.90% test_error 15.00%
# 678 acc_train_loss 47.30 acc_train_error 0.90% test_error 15.00%
# 679 acc_train_loss 47.27 acc_train_error 0.90% test_error 15.00%
# 680 acc_train_loss 47.24 acc_train_error 0.90% test_error 15.00%
# 681 acc_train_loss 47.21 acc_train_error 0.90% test_error 15.00%
# 682 acc_train_loss 47.18 acc_train_error 0.90% test_error 15.00%
# 683 acc_train_loss 47.15 acc_train_error 0.90% test_error 15.00%
# 684 acc_train_loss 47.13 acc_train_error 0.90% test_error 15.00%
# 685 acc_train_loss 47.10 acc_train_error 0.90% test_error 15.00%
# 686 acc_train_loss 47.07 acc_train_error 0.90% test_error 15.00%
# 687 acc_train_loss 47.04 acc_train_error 0.90% test_error 15.00%
# 688 acc_train_loss 47.02 acc_train_error 0.90% test_error 15.00%
# 689 acc_train_loss 46.99 acc_train_error 0.90% test_error 15.00%
# 690 acc_train_loss 46.96 acc_train_error 0.90% test_error 15.00%
# 691 acc_train_loss 46.93 acc_train_error 0.90% test_error 15.00%
# 692 acc_train_loss 46.91 acc_train_error 0.90% test_error 15.00%
# 693 acc_train_loss 46.88 acc_train_error 0.90% test_error 15.00%
# 694 acc_train_loss 46.85 acc_train_error 0.90% test_error 15.00%
# 695 acc_train_loss 46.82 acc_train_error 0.90% test_error 15.00%
# 696 acc_train_loss 46.80 acc_train_error 0.90% test_error 15.00%
# 697 acc_train_loss 46.77 acc_train_error 0.90% test_error 15.00%
# 698 acc_train_loss 46.74 acc_train_error 0.90% test_error 15.00%
# 699 acc_train_loss 46.72 acc_train_error 0.90% test_error 15.00%
# 700 acc_train_loss 46.69 acc_train_error 0.90% test_error 15.00%
# 701 acc_train_loss 46.67 acc_train_error 0.90% test_error 15.00%
# 702 acc_train_loss 46.64 acc_train_error 0.90% test_error 15.00%
# 703 acc_train_loss 46.61 acc_train_error 0.90% test_error 15.00%
# 704 acc_train_loss 46.59 acc_train_error 0.90% test_error 15.00%
# 705 acc_train_loss 46.56 acc_train_error 0.90% test_error 15.00%
# 706 acc_train_loss 46.54 acc_train_error 0.90% test_error 15.00%
# 707 acc_train_loss 46.51 acc_train_error 0.90% test_error 15.00%
# 708 acc_train_loss 46.48 acc_train_error 0.90% test_error 15.00%
# 709 acc_train_loss 46.46 acc_train_error 0.90% test_error 15.00%
# 710 acc_train_loss 46.43 acc_train_error 0.90% test_error 15.00%
# 711 acc_train_loss 46.41 acc_train_error 0.90% test_error 15.00%
# 712 acc_train_loss 46.38 acc_train_error 0.90% test_error 15.00%
# 713 acc_train_loss 46.36 acc_train_error 0.90% test_error 15.00%
# 714 acc_train_loss 46.33 acc_train_error 0.90% test_error 15.00%
# 715 acc_train_loss 46.31 acc_train_error 0.90% test_error 15.00%
# 716 acc_train_loss 46.28 acc_train_error 0.90% test_error 15.00%
# 717 acc_train_loss 46.26 acc_train_error 0.90% test_error 15.00%
# 718 acc_train_loss 46.23 acc_train_error 0.90% test_error 15.00%
# 719 acc_train_loss 46.21 acc_train_error 0.90% test_error 15.00%
# 720 acc_train_loss 46.18 acc_train_error 0.90% test_error 15.00%
# 721 acc_train_loss 46.16 acc_train_error 0.90% test_error 15.00%
# 722 acc_train_loss 46.13 acc_train_error 0.90% test_error 15.00%
# 723 acc_train_loss 46.11 acc_train_error 0.90% test_error 15.00%
# 724 acc_train_loss 46.09 acc_train_error 0.90% test_error 15.00%
# 725 acc_train_loss 46.06 acc_train_error 0.90% test_error 15.00%
# ...
# 754 acc_train_loss 45.39 acc_train_error 0.90% test_error 15.00%
# 755 acc_train_loss 45.36 acc_train_error 0.90% test_error 15.00%
# 756 acc_train_loss 45.34 acc_train_error 0.90% test_error 15.00%
# 757 acc_train_loss 45.32 acc_train_error 0.90% test_error 15.00%
# 758 acc_train_loss 45.30 acc_train_error 0.90% test_error 15.00%
# 759 acc_train_loss 45.27 acc_train_error 0.90% test_error 15.00%
# 760 acc_train_loss 45.25 acc_train_error 0.90% test_error 15.00%
# 761 acc_train_loss 45.23 acc_train_error 0.90% test_error 15.00%
# 762 acc_train_loss 45.21 acc_train_error 0.90% test_error 15.00%
# 763 acc_train_loss 45.18 acc_train_error 0.90% test_error 15.00%
# 764 acc_train_loss 45.16 acc_train_error 0.90% test_error 15.00%
# 765 acc_train_loss 45.14 acc_train_error 0.90% test_error 15.00%
# 766 acc_train_loss 45.12 acc_train_error 0.90% test_error 15.00%
# 767 acc_train_loss 45.09 acc_train_error 0.90% test_error 15.00%
# 768 acc_train_loss 45.07 acc_train_error 0.90% test_error 15.00%
# 769 acc_train_loss 45.05 acc_train_error 0.90% test_error 15.00%
# 770 acc_train_loss 45.03 acc_train_error 0.90% test_error 15.00%
# 771 acc_train_loss 45.01 acc_train_error 0.90% test_error 15.00%
# 772 acc_train_loss 44.98 acc_train_error 0.90% test_error 15.00%
# 773 acc_train_loss 44.96 acc_train_error 0.90% test_error 15.00%
# 774 acc_train_loss 44.94 acc_train_error 0.90% test_error 15.00%
# 775 acc_train_loss 44.92 acc_train_error 0.90% test_error 15.00%
# 776 acc_train_loss 44.90 acc_train_error 0.90% test_error 15.00%
# 777 acc_train_loss 44.87 acc_train_error 0.90% test_error 15.00%
# 778 acc_train_loss 44.85 acc_train_error 0.90% test_error 15.00%
# 779 acc_train_loss 44.83 acc_train_error 0.90% test_error 15.00%
# 780 acc_train_loss 44.81 acc_train_error 0.90% test_error 15.00%
# 781 acc_train_loss 44.79 acc_train_error 0.90% test_error 15.00%
# 782 acc_train_loss 44.76 acc_train_error 0.90% test_error 15.00%
# 783 acc_train_loss 44.74 acc_train_error 0.90% test_error 15.00%
# 784 acc_train_loss 44.72 acc_train_error 0.90% test_error 15.00%
# 785 acc_train_loss 44.70 acc_train_error 0.90% test_error 15.00%
# 786 acc_train_loss 44.68 acc_train_error 0.90% test_error 15.00%
# 787 acc_train_loss 44.65 acc_train_error 0.90% test_error 15.00%
# 788 acc_train_loss 44.63 acc_train_error 0.90% test_error 15.00%
# 789 acc_train_loss 44.61 acc_train_error 0.90% test_error 15.00%
# 790 acc_train_loss 44.59 acc_train_error 0.90% test_error 15.00%
# 791 acc_train_loss 44.57 acc_train_error 0.90% test_error 15.00%
# 792 acc_train_loss 44.54 acc_train_error 0.90% test_error 15.00%
# 793 acc_train_loss 44.52 acc_train_error 0.90% test_error 15.00%
# 794 acc_train_loss 44.50 acc_train_error 0.90% test_error 15.00%
# 795 acc_train_loss 44.48 acc_train_error 0.90% test_error 15.00%
# 796 acc_train_loss 44.46 acc_train_error 0.90% test_error 15.00%
# 797 acc_train_loss 44.43 acc_train_error 0.90% test_error 15.00%
# 798 acc_train_loss 44.41 acc_train_error 0.90% test_error 15.00%
# 799 acc_train_loss 44.39 acc_train_error 0.90% test_error 15.10%
# 800 acc_train_loss 44.37 acc_train_error 0.90% test_error 15.10%
# 801 acc_train_loss 44.34 acc_train_error 0.90% test_error 15.10%
# 802 acc_train_loss 44.32 acc_train_error 0.90% test_error 15.10%
# 803 acc_train_loss 44.30 acc_train_error 0.90% test_error 15.10%
# 804 acc_train_loss 44.28 acc_train_error 0.90% test_error 15.10%
# 805 acc_train_loss 44.26 acc_train_error 0.90% test_error 15.10%
# 806 acc_train_loss 44.23 acc_train_error 0.90% test_error 15.10%
# 807 acc_train_loss 44.21 acc_train_error 0.90% test_error 15.10%
# 808 acc_train_loss 44.19 acc_train_error 0.90% test_error 15.10%
# 809 acc_train_loss 44.17 acc_train_error 0.90% test_error 15.10%
# 810 acc_train_loss 44.14 acc_train_error 0.90% test_error 15.10%
# 811 acc_train_loss 44.12 acc_train_error 0.90% test_error 15.10%
# 812 acc_train_loss 44.10 acc_train_error 0.90% test_error 15.10%
# 813 acc_train_loss 44.07 acc_train_error 0.90% test_error 15.10%
# 814 acc_train_loss 44.05 acc_train_error 0.90% test_error 15.10%
# 815 acc_train_loss 44.03 acc_train_error 0.90% test_error 15.10%
# 816 acc_train_loss 44.01 acc_train_error 0.80% test_error 15.10%
# 817 acc_train_loss 43.98 acc_train_error 0.80% test_error 15.10%
# 818 acc_train_loss 43.96 acc_train_error 0.80% test_error 15.10%
# 819 acc_train_loss 43.94 acc_train_error 0.80% test_error 15.10%
# 820 acc_train_loss 43.91 acc_train_error 0.80% test_error 15.10%
# 821 acc_train_loss 43.89 acc_train_error 0.80% test_error 15.10%
# 822 acc_train_loss 43.87 acc_train_error 0.80% test_error 15.10%
# 823 acc_train_loss 43.84 acc_train_error 0.80% test_error 15.10%
# 824 acc_train_loss 43.82 acc_train_error 0.80% test_error 15.10%
# 825 acc_train_loss 43.80 acc_train_error 0.80% test_error 15.10%
# 826 acc_train_loss 43.77 acc_train_error 0.80% test_error 15.10%
# 827 acc_train_loss 43.75 acc_train_error 0.80% test_error 15.10%
# 828 acc_train_loss 43.73 acc_train_error 0.80% test_error 15.10%
# 829 acc_train_loss 43.70 acc_train_error 0.80% test_error 15.10%
# 830 acc_train_loss 43.68 acc_train_error 0.80% test_error 15.10%
# 831 acc_train_loss 43.65 acc_train_error 0.80% test_error 15.10%
# 832 acc_train_loss 43.63 acc_train_error 0.80% test_error 15.10%
# 833 acc_train_loss 43.61 acc_train_error 0.80% test_error 15.10%
# 834 acc_train_loss 43.58 acc_train_error 0.80% test_error 15.10%
# 835 acc_train_loss 43.56 acc_train_error 0.80% test_error 15.10%
# 836 acc_train_loss 43.53 acc_train_error 0.80% test_error 15.10%
# 837 acc_train_loss 43.51 acc_train_error 0.80% test_error 15.10%
# 838 acc_train_loss 43.48 acc_train_error 0.80% test_error 15.10%
# 839 acc_train_loss 43.46 acc_train_error 0.80% test_error 15.10%
# 840 acc_train_loss 43.43 acc_train_error 0.80% test_error 15.10%
# 841 acc_train_loss 43.41 acc_train_error 0.80% test_error 15.10%
# 842 acc_train_loss 43.38 acc_train_error 0.80% test_error 15.10%
# 843 acc_train_loss 43.36 acc_train_error 0.80% test_error 15.10%
# 844 acc_train_loss 43.33 acc_train_error 0.80% test_error 15.10%
# 845 acc_train_loss 43.31 acc_train_error 0.80% test_error 15.10%
# 846 acc_train_loss 43.28 acc_train_error 0.80% test_error 15.10%
# 847 acc_train_loss 43.26 acc_train_error 0.80% test_error 15.10%
# 848 acc_train_loss 43.23 acc_train_error 0.80% test_error 15.10%
# 849 acc_train_loss 43.20 acc_train_error 0.80% test_error 15.10%
# 850 acc_train_loss 43.18 acc_train_error 0.80% test_error 15.10%
# 851 acc_train_loss 43.15 acc_train_error 0.80% test_error 15.10%
# 852 acc_train_loss 43.12 acc_train_error 0.80% test_error 15.10%
# 853 acc_train_loss 43.10 acc_train_error 0.80% test_error 15.10%
# 854 acc_train_loss 43.07 acc_train_error 0.80% test_error 15.10%
# 855 acc_train_loss 43.04 acc_train_error 0.80% test_error 15.10%
# 856 acc_train_loss 43.02 acc_train_error 0.80% test_error 15.10%
# 857 acc_train_loss 42.99 acc_train_error 0.80% test_error 15.10%
# 858 acc_train_loss 42.96 acc_train_error 0.80% test_error 15.10%
# 859 acc_train_loss 42.94 acc_train_error 0.80% test_error 15.30%
# 860 acc_train_loss 42.91 acc_train_error 0.80% test_error 15.30%
# 861 acc_train_loss 42.88 acc_train_error 0.80% test_error 15.30%
# 862 acc_train_loss 42.85 acc_train_error 0.80% test_error 15.30%
# 863 acc_train_loss 42.82 acc_train_error 0.80% test_error 15.30%
# 864 acc_train_loss 42.80 acc_train_error 0.80% test_error 15.30%
# 865 acc_train_loss 42.77 acc_train_error 0.80% test_error 15.30%
# 866 acc_train_loss 42.74 acc_train_error 0.80% test_error 15.30%
# 867 acc_train_loss 42.71 acc_train_error 0.80% test_error 15.30%
# 868 acc_train_loss 42.68 acc_train_error 0.80% test_error 15.30%
# 869 acc_train_loss 42.65 acc_train_error 0.80% test_error 15.30%
# 870 acc_train_loss 42.62 acc_train_error 0.80% test_error 15.30%
# 871 acc_train_loss 42.59 acc_train_error 0.80% test_error 15.20%
# 872 acc_train_loss 42.56 acc_train_error 0.80% test_error 15.20%
# 873 acc_train_loss 42.53 acc_train_error 0.80% test_error 15.20%
# 874 acc_train_loss 42.50 acc_train_error 0.80% test_error 15.20%
# 875 acc_train_loss 42.47 acc_train_error 0.80% test_error 15.20%
# 876 acc_train_loss 42.44 acc_train_error 0.80% test_error 15.20%
# 877 acc_train_loss 42.41 acc_train_error 0.80% test_error 15.20%
# 878 acc_train_loss 42.38 acc_train_error 0.80% test_error 15.20%
# 879 acc_train_loss 42.35 acc_train_error 0.80% test_error 15.20%
# 880 acc_train_loss 42.32 acc_train_error 0.80% test_error 15.20%
# 881 acc_train_loss 42.29 acc_train_error 0.80% test_error 15.20%
# 882 acc_train_loss 42.25 acc_train_error 0.80% test_error 15.20%
# 883 acc_train_loss 42.22 acc_train_error 0.80% test_error 15.20%
# 884 acc_train_loss 42.19 acc_train_error 0.80% test_error 15.20%
# 885 acc_train_loss 42.16 acc_train_error 0.80% test_error 15.20%
# 886 acc_train_loss 42.12 acc_train_error 0.80% test_error 15.20%
# 887 acc_train_loss 42.09 acc_train_error 0.80% test_error 15.20%
# 888 acc_train_loss 42.06 acc_train_error 0.80% test_error 15.20%
# 889 acc_train_loss 42.02 acc_train_error 0.80% test_error 15.20%
# 890 acc_train_loss 41.99 acc_train_error 0.80% test_error 15.20%
# 891 acc_train_loss 41.95 acc_train_error 0.80% test_error 15.20%
# 892 acc_train_loss 41.92 acc_train_error 0.80% test_error 15.20%
# 893 acc_train_loss 41.88 acc_train_error 0.80% test_error 15.20%
# 894 acc_train_loss 41.85 acc_train_error 0.80% test_error 15.20%
# 895 acc_train_loss 41.81 acc_train_error 0.80% test_error 15.20%
# 896 acc_train_loss 41.77 acc_train_error 0.80% test_error 15.20%
# 897 acc_train_loss 41.74 acc_train_error 0.80% test_error 15.20%
# 898 acc_train_loss 41.70 acc_train_error 0.80% test_error 15.20%
# 899 acc_train_loss 41.66 acc_train_error 0.80% test_error 15.20%
# 900 acc_train_loss 41.62 acc_train_error 0.80% test_error 15.20%
# 901 acc_train_loss 41.58 acc_train_error 0.80% test_error 15.20%
# 902 acc_train_loss 41.54 acc_train_error 0.80% test_error 15.30%
# 903 acc_train_loss 41.50 acc_train_error 0.80% test_error 15.40%
# 904 acc_train_loss 41.46 acc_train_error 0.80% test_error 15.40%
# 905 acc_train_loss 41.41 acc_train_error 0.80% test_error 15.40%
# 906 acc_train_loss 41.37 acc_train_error 0.80% test_error 15.40%
# 907 acc_train_loss 41.32 acc_train_error 0.80% test_error 15.40%
# 908 acc_train_loss 41.28 acc_train_error 0.80% test_error 15.40%
# 909 acc_train_loss 41.23 acc_train_error 0.80% test_error 15.40%
# 910 acc_train_loss 41.18 acc_train_error 0.80% test_error 15.40%
# 911 acc_train_loss 41.14 acc_train_error 0.80% test_error 15.40%
# 912 acc_train_loss 41.09 acc_train_error 0.80% test_error 15.40%
# 913 acc_train_loss 41.04 acc_train_error 0.80% test_error 15.40%
# 914 acc_train_loss 40.99 acc_train_error 0.80% test_error 15.40%
# 915 acc_train_loss 40.94 acc_train_error 0.80% test_error 15.40%
# 916 acc_train_loss 40.89 acc_train_error 0.80% test_error 15.30%
# 917 acc_train_loss 40.84 acc_train_error 0.80% test_error 15.30%
# 918 acc_train_loss 40.79 acc_train_error 0.80% test_error 15.30%
# 919 acc_train_loss 40.74 acc_train_error 0.80% test_error 15.30%
# 920 acc_train_loss 40.69 acc_train_error 0.80% test_error 15.30%
# 921 acc_train_loss 40.65 acc_train_error 0.80% test_error 15.30%
# 922 acc_train_loss 40.60 acc_train_error 0.80% test_error 15.30%
# 923 acc_train_loss 40.56 acc_train_error 0.80% test_error 15.30%
# 924 acc_train_loss 40.52 acc_train_error 0.80% test_error 15.30%
# 925 acc_train_loss 40.48 acc_train_error 0.80% test_error 15.40%
# 926 acc_train_loss 40.45 acc_train_error 0.80% test_error 15.40%
# 927 acc_train_loss 40.41 acc_train_error 0.80% test_error 15.40%
# 928 acc_train_loss 40.37 acc_train_error 0.80% test_error 15.40%
# 929 acc_train_loss 40.34 acc_train_error 0.80% test_error 15.40%
# 930 acc_train_loss 40.31 acc_train_error 0.80% test_error 15.40%
# 931 acc_train_loss 40.28 acc_train_error 0.80% test_error 15.40%
# 932 acc_train_loss 40.25 acc_train_error 0.80% test_error 15.40%
# 933 acc_train_loss 40.22 acc_train_error 0.80% test_error 15.40%
# 934 acc_train_loss 40.19 acc_train_error 0.80% test_error 15.40%
# 935 acc_train_loss 40.17 acc_train_error 0.80% test_error 15.40%
# 936 acc_train_loss 40.14 acc_train_error 0.80% test_error 15.40%
# 937 acc_train_loss 40.12 acc_train_error 0.80% test_error 15.40%
# 938 acc_train_loss 40.09 acc_train_error 0.80% test_error 15.40%
# 939 acc_train_loss 40.07 acc_train_error 0.80% test_error 15.40%
# 940 acc_train_loss 40.05 acc_train_error 0.80% test_error 15.40%
# 941 acc_train_loss 40.02 acc_train_error 0.80% test_error 15.40%
# 942 acc_train_loss 40.00 acc_train_error 0.80% test_error 15.40%
# 943 acc_train_loss 39.98 acc_train_error 0.80% test_error 15.40%
# 944 acc_train_loss 39.96 acc_train_error 0.80% test_error 15.40%
# 945 acc_train_loss 39.94 acc_train_error 0.80% test_error 15.40%
# 946 acc_train_loss 39.92 acc_train_error 0.80% test_error 15.40%
# 947 acc_train_loss 39.90 acc_train_error 0.80% test_error 15.40%
# 948 acc_train_loss 39.88 acc_train_error 0.80% test_error 15.40%
# 949 acc_train_loss 39.86 acc_train_error 0.80% test_error 15.40%
# 950 acc_train_loss 39.84 acc_train_error 0.80% test_error 15.40%
# 951 acc_train_loss 39.82 acc_train_error 0.80% test_error 15.40%
# 952 acc_train_loss 39.80 acc_train_error 0.80% test_error 15.40%
# 953 acc_train_loss 39.78 acc_train_error 0.80% test_error 15.40%
# 954 acc_train_loss 39.76 acc_train_error 0.80% test_error 15.40%
# 955 acc_train_loss 39.74 acc_train_error 0.80% test_error 15.40%
# 956 acc_train_loss 39.73 acc_train_error 0.80% test_error 15.40%
# 957 acc_train_loss 39.71 acc_train_error 0.80% test_error 15.40%
# 958 acc_train_loss 39.69 acc_train_error 0.80% test_error 15.40%
# 959 acc_train_loss 39.67 acc_train_error 0.80% test_error 15.40%
# 960 acc_train_loss 39.66 acc_train_error 0.80% test_error 15.40%
# 961 acc_train_loss 39.64 acc_train_error 0.80% test_error 15.40%
# 962 acc_train_loss 39.62 acc_train_error 0.80% test_error 15.40%
# 963 acc_train_loss 39.61 acc_train_error 0.80% test_error 15.40%
# 964 acc_train_loss 39.59 acc_train_error 0.80% test_error 15.40%
# 965 acc_train_loss 39.57 acc_train_error 0.80% test_error 15.40%
# 966 acc_train_loss 39.56 acc_train_error 0.80% test_error 15.50%
# 967 acc_train_loss 39.54 acc_train_error 0.80% test_error 15.50%
# 968 acc_train_loss 39.53 acc_train_error 0.80% test_error 15.50%
# 969 acc_train_loss 39.51 acc_train_error 0.80% test_error 15.50%
# 970 acc_train_loss 39.50 acc_train_error 0.80% test_error 15.50%
# 971 acc_train_loss 39.48 acc_train_error 0.80% test_error 15.50%
# 972 acc_train_loss 39.46 acc_train_error 0.80% test_error 15.50%
# 973 acc_train_loss 39.45 acc_train_error 0.80% test_error 15.50%
# 974 acc_train_loss 39.43 acc_train_error 0.80% test_error 15.50%
# 975 acc_train_loss 39.42 acc_train_error 0.80% test_error 15.50%
# 976 acc_train_loss 39.41 acc_train_error 0.80% test_error 15.50%
# 977 acc_train_loss 39.39 acc_train_error 0.80% test_error 15.50%
# 978 acc_train_loss 39.38 acc_train_error 0.80% test_error 15.50%
# 979 acc_train_loss 39.36 acc_train_error 0.80% test_error 15.50%
# 980 acc_train_loss 39.35 acc_train_error 0.80% test_error 15.50%
# 981 acc_train_loss 39.33 acc_train_error 0.80% test_error 15.50%
# 982 acc_train_loss 39.32 acc_train_error 0.80% test_error 15.50%
# 983 acc_train_loss 39.30 acc_train_error 0.80% test_error 15.50%
# 984 acc_train_loss 39.29 acc_train_error 0.80% test_error 15.50%
# 985 acc_train_loss 39.28 acc_train_error 0.80% test_error 15.50%
# 986 acc_train_loss 39.26 acc_train_error 0.80% test_error 15.50%
# 987 acc_train_loss 39.25 acc_train_error 0.80% test_error 15.50%
# 988 acc_train_loss 39.24 acc_train_error 0.80% test_error 15.50%
# 989 acc_train_loss 39.22 acc_train_error 0.80% test_error 15.50%
# 990 acc_train_loss 39.21 acc_train_error 0.80% test_error 15.50%
# 991 acc_train_loss 39.19 acc_train_error 0.80% test_error 15.50%
# 992 acc_train_loss 39.18 acc_train_error 0.80% test_error 15.50%
# 993 acc_train_loss 39.17 acc_train_error 0.80% test_error 15.50%
# 994 acc_train_loss 39.16 acc_train_error 0.80% test_error 15.50%
# 995 acc_train_loss 39.14 acc_train_error 0.80% test_error 15.50%
# 996 acc_train_loss 39.13 acc_train_error 0.80% test_error 15.50%
# 997 acc_train_loss 39.12 acc_train_error 0.80% test_error 15.50%
# 998 acc_train_loss 39.10 acc_train_error 0.80% test_error 15.50%
# 999 acc_train_loss 39.09 acc_train_error 0.80% test_error 15.50%
